# %%
# !uv venv .venv
# !uv pip install -r requirements.txt
# Out:
# Running cells with '.venv (3.10.12) (Python 3.10.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/user/workspace/BoketeDBv3_/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import os

target_dirs = [
    "BoketeDBv3",
    "BoketeDBv3/images",
    "BoketeDBv3/odai_db",
    "BoketeDBv3/boke_db"
]
for D in target_dirs:
    os.makedirs(D, exist_ok=True)
